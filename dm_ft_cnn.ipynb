# %%
import numpy
print(numpy.__version__)
import networkx
print(networkx.__version__)

from nilmtk.api import API
import warnings

warnings.filterwarnings("ignore")
from nilmtk.disaggregate import GaterCNN
import nilmtk.utils as utils
# Out:
# 1.24.3
# 2.8.4

# %%
import torch
import torch.nn.functional as F
from torch.utils.data import Dataset
# import pytorch_lightning as pl

import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import os

# from src import *

USE_GPU = True
device = torch.device("cuda:0" if USE_GPU and torch.cuda.is_available() else "cpu")
print(torch.__version__, device)
# Out:
# 2.0.1 cuda:0

# %%
DATASET_NAME = 'redd'
HOUSE = 1
TUNE = True
days = 2
MODEL_NOTE = f"{days}days_ft_{HOUSE}"

if HOUSE == 1:
    TRAIN = {
        # 1: {
        #     'start_time': '2011-04-19',
        #     'end_time': '2011-04-26'
        # },
        1: {
            'start_time': '2011-04-22',
            'end_time': '2011-04-24'
        },
    }
    TEST = {
        1: {
            'start_time': '2011-04-24',
            'end_time': '2011-05-26'
        },
    }
elif HOUSE == 2:
    TRAIN = {
        # 2: {
        #     'start_time': '2011-04-18',
        #     'end_time': '2011-04-25'
        # },
        2: {
            'start_time': '2011-04-22',
            'end_time': '2011-04-24'
        },
    }
    TEST = {
        2: {
            'start_time': '2011-04-25',
            'end_time': '2011-05-22'
        },
    }
elif HOUSE == 3:
    TRAIN = {
        # 3: {
        #     'start_time': '2011-04-17',
        #     'end_time': '2011-04-24'
        # },
        3: {
            'start_time': '2011-04-22',
            'end_time': '2011-04-24'
        },
    }
    TEST = {
        3: {
            'start_time': '2011-04-24',
            'end_time': '2011-05-30'
        },
    }
else:
    raise NameError

e = {
    # Specify power type, sample rate and disaggregated appliance
    'power': {
        'mains_train': ['apparent'],
        'mains_transfer': ['apparent'],
        'mains_test': ['apparent'],
                
        # 'appliance': ['active']
        # 'mains': ['apparent'],  # problem: ukdale active, redd apparent
        'appliance': ['active'],
    },
    'sample_rate': 6,
    # 'appliances': ['washing machine'],
    'appliances': ['fridge'],
    # Universally no pre-training
    'pre_trained': False,
    "app_meta": utils.GENERAL_APP_META,
    # Specify algorithm hyper-parameters
    # 'gater': 
    #     # "GaterSGN": GaterSGN(
    #     # {'n_epochs': 10, 'batch_size': 256, 'test_only': False}),
    #     SGN({'n_epochs': 5, 'batch_size': 256, 'test_only': True, 'gate_only': True, 'note': 'ukdale'})
    #     ,
    'save_note': f'ft-{HOUSE}' if TUNE else f'ft-{HOUSE}-no',
    'methods': {
        # "DM_GATE2": DM_GATE2(
        #     {'n_epochs': 5, 'batch_size': 64, 'sequence_length': 720, 'overlapping_step': 10,
        #     'test_only': True, 'fine_tune': TUNE, 'src_rate': 0.0, 'lr': 5e-6, "sampler": "ddim", "patience": 3,
        #     'freeze': True,
        #     "app_meta": utils.APP_META[DATASET_NAME], 'filter_train': False, 'note': DATASET_NAME, 'load_from': 'ukdale'})
        
        "GaterCNN": GaterCNN(
            {'n_epochs': 20, 'batch_size': 128,
             'sequence_length': 720, 'appliance_length': 720,
             'test_only': True, 'fine_tune': TUNE,
             'note': MODEL_NOTE, 'load_from': 'ukdale',
             'patience': 3}
        )
    },
    # Specify train and test data
    'train': {
        'datasets': {
            # 'ukdale': {
            #     'path': 'mnt/ukdale.h5',
            #     'buildings': {
            #         1: {
            #             'start_time': '2013-05-31',
            #             'end_time': '2013-08-31'
            #         },
            #         5: {
            #             'start_time': '2014-07-01',
            #             'end_time': '2014-09-05'
            #         },
            #     }
            # },
            'redd': {
                'path': 'mnt/redd.h5',
                'buildings': TRAIN
            },
        }
    },
    'transfer': {
        'datasets': {
            'redd': {
                'path': 'mnt/redd.h5',
                'buildings': TRAIN
            },
        },
    },
    'test': {
        'datasets': {
            'redd': {
                'path': 'mnt/redd.h5',
                'buildings': TEST
            },
        },
        # Specify evaluation metrics
        'metrics': ['accuracy', 'f1score', 'mae', 'sae', 'precision', 'recall', 'nep', 'MCC']
    }
}

API(e)
# Out:
# SGN
# Started training for  SGN
# Joint training for  SGN
# ............... Loading Data for training ...................
# Loading data for  redd  dataset
# Loading building ...  1
# Loading data for meter ElecMeterID(instance=1, building=1, dataset='REDD')     {'fill_method': None, 'how': 'mean'}
# Loading data for meter ElecMeterID(instance=2, building=1, dataset='REDD')     {'fill_method': None, 'how': 'mean'}
#
# Done loading data all meters for this chunk.
# {'fill_method': None, 'how': 'mean'}
# Dropping missing values
# Train Jointly
# Loading transfer data for  redd  dataset
# Loading building ...  1
# Loading data for meter ElecMeterID(instance=1, building=1, dataset='REDD')     {'fill_method': None, 'how': 'mean'}
# Loading data for meter ElecMeterID(instance=2, building=1, dataset='REDD')     {'fill_method': None, 'how': 'mean'}
#
# Done loading data all meters for this chunk.
# {'fill_method': None, 'how': 'mean'}
# Dropping missing values
# Transfer Jointly
# ...............SGN partial_fit running...............
# Processing tuning data
# First model training for  fridge
# Fine tuning
# <class 'numpy.ndarray'> <class 'numpy.ndarray'>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 142
#      59     raise NameError
#      61 e = {
#      62     # Specify power type, sample rate and disaggregated appliance
#      63     'power': {
#    (...)
#     139     }
#     140 }
# --> 142 API(e)
#
# File d:\GitHub\NeuralNILM_Pytorch\nilmtk\api.py:80, in API.__init__(self, params)
#      78 self.artificial_aggregate = params.get('artificial_aggregate', self.artificial_aggregate)
#      79 self.chunk_size = params.get('chunk_size', self.chunk_size)
# ---> 80 self.experiment(params)
#
# File d:\GitHub\NeuralNILM_Pytorch\nilmtk\api.py:103, in API.experiment(self, params)
#     100             continue
#     102     print("Joint training for ", clf.MODEL_NAME)
# --> 103     self.train_jointly(clf, d, trans)
#     104     print("Finished training for ", clf.MODEL_NAME)
#     106 d = self.test_datasets_dict
#
# File d:\GitHub\NeuralNILM_Pytorch\nilmtk\api.py:233, in API.train_jointly(self, clf, d, trans_d)
#     231 # print("Train and Transfer", self.train_mains, self.transfer_mains)
#     232 if self.transfer_dataset_dict is not None:
# --> 233     clf.partial_fit(self.train_mains, self.train_submeters, self.pre_trained, True,
#     234                     dst_main=self.transfer_mains, dst_appliances=self.transfer_submeters)
#     235 else:
#     236     clf.partial_fit(self.train_mains, self.train_submeters, self.pre_trained, True)
#
# File d:\GitHub\NeuralNILM_Pytorch\nilmtk\disaggregate\sgn_pytorch.py:484, in SGN.partial_fit(self, train_main, train_appliances, pretrain, do_preprocessing, **load_kwargs)
#     481 print(type(power), type(app_dst_power))
#     482 # model.freeze(True)
# --> 484 fine_tune(appliance_name, model,
#     485           transfer_main, app_dst_power,
#     486           self.n_epochs,
#     487           self.batch_size,
#     488           (15.0 - self.appliance_params[appliance_name]['mean']) /
#     489           self.appliance_params[appliance_name]['std'],
#     490           model_note=self.note,
#     491           checkpoint_interval=3,
#     492           train_patience=3,
#     493           lr=1e-4,
#     494           src_dataset=self.load_from,
#     495           weight_decay=self.weight_decay)
#     497 ckpt_name = "./" + appliance_name + "_" + self.note + "_sgn_best_state_dict.pt"
#     498 # ckpt_name = "./fridge_dm_checkpoint_26_epoch.pt"
#
# File d:\GitHub\NeuralNILM_Pytorch\nilmtk\disaggregate\sgn_pytorch.py:129, in fine_tune(appliance_name, model, mains, appliance, epochs, batch_size, threshold, model_note, checkpoint_interval, train_patience, lr, src_dataset, weight_decay)
#     126 base_name = "./" + appliance_name + "_" + model_note + "_sgn"
#     128 model.freeze(True)
# --> 129 summary(model, (1, mains.shape[1]))
#     130 # Split the train and validation set
#     131 train_mains, valid_mains, train_appliance, valid_appliance = train_test_split(mains, appliance,
#     132                                                                               test_size=.2,
#     133                                                                               random_state=random_seed)
#
# File c:\ProgramData\Anaconda3\envs\py310\lib\site-packages\torchsummary\torchsummary.py:72, in summary(model, input_size, batch_size, device)
#      68 model.apply(register_hook)
#      70 # make a forward pass
#      71 # print(x.shape)
# ---> 72 model(*x)
#      74 # remove these hooks
#      75 for h in hooks:
#
# File c:\ProgramData\Anaconda3\envs\py310\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File d:\GitHub\NeuralNILM_Pytorch\nilmtk\disaggregate\sgn_pytorch.py:92, in sgn_Pytorch.forward(self, x)
#      91 def forward(self, x):
# ---> 92     reg_power = self.reg(x)
#      93     app_state = self.act(self.gate(x))
#      94     app_power = reg_power * app_state + (1 - app_state) * self.b
#
# File c:\ProgramData\Anaconda3\envs\py310\lib\site-packages\torch\nn\modules\module.py:1538, in Module._call_impl(self, *args, **kwargs)
#    1535     bw_hook = hooks.BackwardHook(self, full_backward_hooks, backward_pre_hooks)
#    1536     args = bw_hook.setup_input_hook(args)
# -> 1538 result = forward_call(*args, **kwargs)
#    1539 if _global_forward_hooks or self._forward_hooks:
#    1540     for hook_id, hook in (
#    1541         *_global_forward_hooks.items(),
#    1542         *self._forward_hooks.items(),
#    1543     ):
#
# File d:\GitHub\NeuralNILM_Pytorch\nilmtk\disaggregate\sgn_pytorch.py:71, in sgn_branch_network.forward(self, x)
#      69 def forward(self, x):
#      70     x = self.conv(x)
# ---> 71     x = self.dense(x.view(-1, 50 * self.mains_length))
#      72     return x.view(-1, self.appliance_length)
#
# File c:\ProgramData\Anaconda3\envs\py310\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\ProgramData\Anaconda3\envs\py310\lib\site-packages\torch\nn\modules\container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File c:\ProgramData\Anaconda3\envs\py310\lib\site-packages\torch\nn\modules\module.py:1538, in Module._call_impl(self, *args, **kwargs)
#    1535     bw_hook = hooks.BackwardHook(self, full_backward_hooks, backward_pre_hooks)
#    1536     args = bw_hook.setup_input_hook(args)
# -> 1538 result = forward_call(*args, **kwargs)
#    1539 if _global_forward_hooks or self._forward_hooks:
#    1540     for hook_id, hook in (
#    1541         *_global_forward_hooks.items(),
#    1542         *self._forward_hooks.items(),
#    1543     ):
#
# File c:\ProgramData\Anaconda3\envs\py310\lib\site-packages\torch\nn\modules\linear.py:114, in Linear.forward(self, input)
#     113 def forward(self, input: Tensor) -> Tensor:
# --> 114     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:
